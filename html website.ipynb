# %%
from IPython.display import display, HTML

# %%
html_code = """
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1">
  <title>Dr. Mohamed Hasain N</title>
  <style>
    body {
      font-family: Arial, sans-serif;
      margin: 0;
      padding: 20px;
      background: #f9f9f9;
      color: #333;
    }
    header {
      background: #004080;
      color: white;
      padding: 20px;
      text-align: center;
    }
    h1, h2 {
      color: #004080;
    }
    section {
      margin-bottom: 30px;
    }
    .contact a {
      margin-right: 15px;
      text-decoration: none;
      color: #004080;
    }
    ul {
      list-style-type: disc;
      padding-left: 20px;
    }
    .publication {
      margin-bottom: 10px;
    }
    footer {
      margin-top: 50px;
      font-style: italic;
    }
  </style>
</head>
<body>

<header>
  <h1>Dr. Mohamed Hasain N</h1>
  <p>Postdoctoral Researcher, IIT Bombay</p>
  <p>Email: <a href="mailto:mohamedhasaincivil@gmail.com">mohamedhasaincivil@gmail.com</a> | Phone: +91-8870939411</p>
  <div class="contact">
    <a href="#">Google Scholar</a> |
    <a href="#">ORCID</a> |
    <a href="#">Scopus</a>
  </div>
</header>

<section>
  <h2>Research Interests</h2>
  <ul>
    <li>Traffic Microsimulation</li>
    <li>Surrogate Safety Analysis</li>
    <li>Transportation Network Resilience</li>
    <li>Intelligent Transportation Systems</li>
    <li>Data-Driven Modelling</li>
    <li>Direct Demand Modelling</li>
  </ul>
</section>

<section>
  <h2>Education</h2>
  <ul>
    <li><strong>Ph.D. in Transportation Engineering</strong>, NIT Silchar (2020–2024) | 9.27 CGPA</li>
    <li><strong>M.Tech. in Transportation Engineering</strong>, NIT Silchar (2018–2020) | 9.42 CGPA (Silver Medallist)</li>
    <li><strong>B.E. in Civil Engineering</strong>, Anna University, Trichy (2013–2017) | 8.09 CGPA</li>
  </ul>
</section>

<section>
  <h2>Current Position</h2>
  <p><strong>Postdoctoral Researcher</strong>, Transportation Systems Engineering Lab, IIT Bombay (2024–Present)</p>
  <ul>
    <li>Resilience analysis of urban transport networks using GPS and rainfall data</li>
    <li>ML-based direct demand modelling for transit ridership in emerging economies</li>
    <li>Working on ADB-funded TUTEM project with IIT Kharagpur, BITS Pilani, and Location Mind</li>
  </ul>
</section>

<section>
  <h2>Relevant Experience</h2>
  <p><strong>Teaching Assistant</strong></p>
  <ul>
    <li>IIT Bombay: Geometric Design and Analysis of High-Speed Roadways</li>
    <li>NIT Silchar: Traffic Engineering, Highway Lab, Surveying, Engineering Graphics and Design</li>
    <li>Mentored UG and PG students on traffic simulation and data modelling</li>
  </ul>
</section>

<section>
  <h2>Research Projects</h2>
  <ul>
    <li><strong>Surrogate Safety Evaluation under Heterogeneous Traffic</strong>: Used PET, TTC, and EVT for crash validation</li>
    <li><strong>Microsimulation-Based Traffic Safety Enhancement</strong>: Calibrated VISSIM with MATLAB GAs; applied surrogate safety and EVT</li>
    <li><strong>Ridership Modeling using ML Techniques</strong>: Applied ML models (DT, RF, GBDT, LightGBM, CatBoost, AdaBoost, XGBoost, KNN, RN, SVR, DNN)</li>
  </ul>
</section>

<section>
  <h2>Technical Skills</h2>
  <ul>
    <li><strong>Traffic Simulation:</strong> VISSIM</li>
    <li><strong>Programming:</strong> Python, MATLAB</li>
    <li><strong>Data Analysis:</strong> Pandas, NumPy, scikit-learn, TensorFlow</li>
    <li><strong>Other Tools:</strong> QGIS, Excel (advanced), Civil3D</li>
  </ul>
</section>

<section>
  <h2>Publications</h2>
  <h3>Journals</h3>
  <div class="publication">1. Hasain, N. M. & Ahmed, M. A. (2025). <em>IATSS Research</em> (In Press).</div>
  <div class="publication">2. Maddu, K., Jena, S., & Hasain, N. M. (2025). <a href="https://doi.org/10.1080/03081060.2025.2487864">Transportation Planning and Technology</a>.</div>
  <div class="publication">3. Hasain, N. M. & Ahmed, M. A. (2024). <a href="https://doi.org/10.1080/21680566.2024.2350520">Transportmetrica B</a>.</div>
  <div class="publication">... (list continues)</div>

  <h3>Book Chapters & Proceedings</h3>
  <ul>
    <li><a href="https://doi.org/10.1007/978-981-96-1037-2_6">Lecture Notes in Civil Engineering, 426</a></li>
    <li><a href="https://doi.org/10.1088/1755-1315/796/1/012016">IOP Conf. Series: Earth and Environmental Science</a></li>
  </ul>

  <h3>Conference Presentations</h3>
  <ul>
    <li>CTRG 2023, SVNIT Surat</li>
    <li>CBRICE 2021, Manipal University, Jaipur</li>
    <li>TPMDC 2020, IIT Bombay</li>
  </ul>
</section>

<section>
  <h2>Professional Service</h2>
  <ul>
    <li>Organizing Committee Member & Session Coordinator: 15th TPMDC 2024, IIT Bombay</li>
    <li>Organizing Committee Member: STRIDE 2025, IIT Bombay</li>
    <li>Proposal Writer: Suzuki Innovation Centre (SIC)</li>
  </ul>
</section>

<section>
  <h2>Manuscript Review</h2>
  <ul>
    <li>Advances in Transportation Studies</li>
    <li>Transportation in Developing Economies</li>
    <li>Asian Transport Studies</li>
  </ul>
</section>

<section>
  <h2>References</h2>
  <p>Available upon request.</p>
</section>

<section>
  <h2>Declaration</h2>
  <p>I (Dr. Mohamed Hasain N) hereby declare that all the information furnished above is true to the best of my knowledge and bear the responsibility of the details.</p>
  <p><strong>Place:</strong> Bombay, India<br>
     <strong>Date:</strong> 11-05-2025<br><br>
     <em>Yours Sincerely,</em><br>
     <strong>Dr. Mohamed Hasain N</strong>
  </p>
</section>

<footer>
  &copy; 2025 Dr. Mohamed Hasain N. All rights reserved.
</footer>

</body>
</html>
"""

# %%
display(HTML(html_code))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <title>Dr. Mohamed Hasain N</title>
#   <style>
#     body {
#       font-family: Arial, sans-serif;
#       margin: 0;
#       padding: 20px;
#       background: #f9f9f9;
#       color: #333;
#     }
#     header {
#       background: #004080;
#       color: white;
#       padding: 20px;
#       text-align: center;
#     }
#     h1, h2 {
#       color: #004080;
#     }
#     section {
#       margin-bottom: 30px;
#     }
#     .contact a {
#       margin-right: 15px;
#       text-decoration: none;
#       color: #004080;
#     }
#     ul {
#       list-style-type: disc;
#       padding-left: 20px;
#     }
#     .publication {
#       margin-bottom: 10px;
#     }
#     footer {
#       margin-top: 50px;
#       font-style: italic;
#     }
#   </style>
# </head>
# <body>
#
# <header>
#   <h1>Dr. Mohamed Hasain N</h1>
# ...
